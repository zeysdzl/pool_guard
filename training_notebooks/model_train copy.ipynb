# %%
import yaml
import os

# Veri setinin ana klasörü
base_path = r"C:\Users\zeyne\Desktop\pool_project\pool_guard_data\raw\Child-Adult Classification.v6i.yolov8"
yaml_path = os.path.join(base_path, "data.yaml")

# Mevcut yaml'ı oku
with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Yolları tam yol (absolute path) olarak güncelle
data['path'] = base_path
data['train'] = "train/images"
data['val'] = "valid/images"
data['test'] = "test/images"

# Sınıf isimlerini garantiye al
data['names'] = {0: 'Adult', 1: 'Child'}

# Dosyayı tekrar kaydet
with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print(f"✅ data.yaml güncellendi: {yaml_path}")
print(f"Sınıflar: {data['names']}")
# Out:
# ✅ data.yaml güncellendi: C:\Users\zeyne\Desktop\pool_project\pool_guard_data\raw\Child-Adult Classification.v6i.yolov8\data.yaml
# Sınıflar: {0: 'Adult', 1: 'Child'}

# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce RTX 5070

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
from ultralytics import YOLO

# 1. Modeli Seç: YOLOv5 Medium (Daha büyük ve zeki bir model)
# 'n' (nano) yerine 'm' (medium) kullanıyoruz. Daha yavaş ama daha isabetli.
model = YOLO("yolov5mu.pt") 

print("🚀 Model Yüklendi: YOLOv5-Medium")

# 2. Eğitimi Başlat
results = model.train(
    data=r"C:\Users\zeyne\Desktop\pool_project\pool_guard_data\raw\Child-Adult Classification.v6i.yolov8\data.yaml",
    epochs=30,          # YOLOv5m biraz daha geç öğrenir, 30 iyidir
    imgsz=640,          # Standart çözünürlük
    batch=8,            # Medium model ağırdır, 8 güvenli (RTX 5070 16 da kaldırabilir)
    device=0,           # GPU
    workers=0,          # Windows için şart
    patience=10,        # 10 epoch boyunca gelişmezse dur
    project="runs/detect",
    name="yolov5m_child_adult", # Kayıt klasörünün adı
    exist_ok=True       # Klasör varsa üzerine yaz
)
# Out:
# ...
# 🚀 Model Yüklendi: YOLOv5-Medium
# Ultralytics 8.3.245  Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...
